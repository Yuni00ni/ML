# %%
# ultralytics와 opencv-python 패키지를 설치
# !pip -q install ultralytics
# !pip -q install opencv-python

import cv2  # OpenCV 라이브러리: 영상 처리에 사용
from ultralytics import YOLO  # Ultralytics YOLO 모델을 사용하기 위한 모듈

# %%
# 코랩에서 학습시킨 best 모델 파일(best.pt)을 로드하여 모델 객체 생성
model = YOLO("./data/best.pt")

# 예측에 사용할 영상 파일의 경로 지정
video_path = "./data/butterfly.mp4"

# 지정된 영상 파일을 읽기 위해 VideoCapture 객체 생성
cap = cv2.VideoCapture(video_path)

# 영상 파일이 열려있는 동안 반복
while cap.isOpened():

    # cap.read() :한 프레임씩 읽기
    # success: 프레임 읽기에 성공했는지 여부 (True/False)
    # frame: 읽어들인 영상 프레임 (이미지 배열)
    success, frame = cap.read()

    # 프레임 읽기에 성공한 경우
    if success:
        # 모델에 현재 프레임을 입력하여 객체 검출 결과를 얻기
        results = model(frame)

        # 결과 중 첫 번째 결과(첫 번째 이미지에 대한 결과)를 시각화하여 annotated_frame 생성
        # plot() 함수는 검출된 객체에 바운딩박스, 라벨 등을 그려서 반환
        annotated_frame = results[0].plot()

        # OpenCV를 사용하여 "YOLO Inference" 창에 주석이 달린 프레임을 표시
        cv2.imshow("YOLO Inference", annotated_frame)

        # 'q' 키를 누르면 while 루프를 종료하여 영상 재생을 중지
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # 더 이상 읽을 프레임이 없으면 루프 종료
        break

# 영상 파일을 닫고 관련 리소스를 해제
cap.release()
# 모든 OpenCV 창을 종료
cv2.destroyAllWindows()
# Out:
# 0: 640x448 1 butterfly, 9 sheeps, 62.3ms
# Speed: 3.1ms preprocess, 62.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 9 sheeps, 80.7ms
# Speed: 4.0ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 9 sheeps, 65.1ms
# Speed: 1.8ms preprocess, 65.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 9 sheeps, 55.3ms
# Speed: 1.9ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 8 sheeps, 62.4ms
# Speed: 2.3ms preprocess, 62.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 8 sheeps, 53.0ms
# Speed: 2.3ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 8 sheeps, 55.2ms
# Speed: 1.9ms preprocess, 55.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 7 sheeps, 56.3ms
# Speed: 3.6ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 7 sheeps, 52.5ms
# Speed: 2.3ms preprocess, 52.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 7 sheeps, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 7 sheeps, 54.4ms
# Speed: 1.9ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 53.3ms
# Speed: 1.8ms preprocess, 53.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 4 sheeps, 51.1ms
# Speed: 2.0ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 52.7ms
# Speed: 1.9ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 4 sheeps, 53.5ms
# Speed: 1.9ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 2 sheeps, 52.4ms
# Speed: 2.2ms preprocess, 52.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 3 sheeps, 53.9ms
# Speed: 2.2ms preprocess, 53.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 3 sheeps, 52.8ms
# Speed: 2.1ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 2 sheeps, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 3 sheeps, 50.9ms
# Speed: 1.9ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 3 sheeps, 49.7ms
# Speed: 1.9ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 51.3ms
# Speed: 2.0ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 4 sheeps, 51.0ms
# Speed: 2.6ms preprocess, 51.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 4 sheeps, 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 49.7ms
# Speed: 1.9ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 51.5ms
# Speed: 2.7ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 butterflys, 5 sheeps, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 4 sheeps, 48.4ms
# Speed: 2.5ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 3 sheeps, 49.9ms
# Speed: 2.1ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 49.7ms
# Speed: 2.2ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 3 sheeps, 72.6ms
# Speed: 4.8ms preprocess, 72.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 4 sheeps, 51.6ms
# Speed: 2.6ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 49.5ms
# Speed: 2.2ms preprocess, 49.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 52.7ms
# Speed: 1.9ms preprocess, 52.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 2 sheeps, 50.4ms
# Speed: 1.8ms preprocess, 50.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 58.0ms
# Speed: 2.2ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 3 sheeps, 51.1ms
# Speed: 1.9ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 2 sheeps, 48.8ms
# Speed: 2.3ms preprocess, 48.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 2 sheeps, 48.5ms
# Speed: 1.8ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 5 sheeps, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 7 sheeps, 48.8ms
# Speed: 1.9ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 50.7ms
# Speed: 2.1ms preprocess, 50.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 52.0ms
# Speed: 1.9ms preprocess, 52.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 6 sheeps, 51.5ms
# Speed: 2.2ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 7 sheeps, 50.2ms
# Speed: 1.7ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.6ms
# Speed: 2.4ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.9ms
# Speed: 2.1ms preprocess, 55.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.6ms
# Speed: 2.3ms preprocess, 56.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.8ms
# Speed: 2.5ms preprocess, 55.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.2ms
# Speed: 2.2ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 59.1ms
# Speed: 2.3ms preprocess, 59.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.3ms
# Speed: 2.4ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.2ms
# Speed: 2.2ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.6ms
# Speed: 2.2ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 67.8ms
# Speed: 2.1ms preprocess, 67.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 63.4ms
# Speed: 3.2ms preprocess, 63.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 53.9ms
# Speed: 2.2ms preprocess, 53.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.6ms
# Speed: 1.9ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.0ms
# Speed: 2.4ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.6ms
# Speed: 2.4ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 60.2ms
# Speed: 2.2ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.5ms
# Speed: 2.1ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.4ms
# Speed: 2.1ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.8ms
# Speed: 2.3ms preprocess, 55.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.5ms
# Speed: 2.3ms preprocess, 55.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.2ms
# Speed: 2.1ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 61.0ms
# Speed: 2.1ms preprocess, 61.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 58.1ms
# Speed: 2.3ms preprocess, 58.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.0ms
# Speed: 2.3ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.1ms
# Speed: 1.9ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.2ms
# Speed: 2.1ms preprocess, 55.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 87.8ms
# Speed: 2.5ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.9ms
# Speed: 2.1ms preprocess, 54.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.9ms
# Speed: 1.9ms preprocess, 55.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.6ms
# Speed: 2.2ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.6ms
# Speed: 2.1ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.5ms
# Speed: 2.1ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.8ms
# Speed: 2.4ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.2ms
# Speed: 2.5ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.1ms
# Speed: 2.3ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.2ms
# Speed: 1.9ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.0ms
# Speed: 2.2ms preprocess, 55.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.6ms
# Speed: 2.3ms preprocess, 54.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 58.3ms
# Speed: 2.1ms preprocess, 58.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.9ms
# Speed: 1.9ms preprocess, 55.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.5ms
# Speed: 2.4ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.8ms
# Speed: 2.3ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.1ms
# Speed: 2.3ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.4ms
# Speed: 2.0ms preprocess, 55.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.2ms
# Speed: 2.2ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 68.9ms
# Speed: 2.0ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 64.7ms
# Speed: 3.2ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.7ms
# Speed: 2.2ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.1ms
# Speed: 2.2ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.3ms
# Speed: 2.6ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.7ms
# Speed: 2.3ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.7ms
# Speed: 2.1ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.1ms
# Speed: 2.1ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.2ms
# Speed: 2.1ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.9ms
# Speed: 2.6ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.0ms
# Speed: 2.1ms preprocess, 57.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.7ms
# Speed: 2.1ms preprocess, 55.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 60.1ms
# Speed: 2.2ms preprocess, 60.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 54.4ms
# Speed: 2.3ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 57.0ms
# Speed: 2.1ms preprocess, 57.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 55.1ms
# Speed: 2.5ms preprocess, 55.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 54.1ms
# Speed: 1.9ms preprocess, 54.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 57.7ms
# Speed: 2.6ms preprocess, 57.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.7ms
# Speed: 2.0ms preprocess, 56.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 55.9ms
# Speed: 2.3ms preprocess, 55.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 73.1ms
# Speed: 1.9ms preprocess, 73.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 65.0ms
# Speed: 3.7ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 57.0ms
# Speed: 2.1ms preprocess, 57.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.9ms
# Speed: 2.5ms preprocess, 56.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.7ms
# Speed: 2.4ms preprocess, 55.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 54.3ms
# Speed: 2.3ms preprocess, 54.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 55.8ms
# Speed: 2.4ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 55.6ms
# Speed: 2.2ms preprocess, 55.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.1ms
# Speed: 2.2ms preprocess, 56.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.7ms
# Speed: 3.1ms preprocess, 56.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 butterflys, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.7ms
# Speed: 2.0ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.1ms
# Speed: 2.4ms preprocess, 56.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.3ms
# Speed: 1.9ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.5ms
# Speed: 2.3ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.5ms
# Speed: 2.2ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 82.0ms
# Speed: 2.2ms preprocess, 82.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 58.7ms
# Speed: 2.6ms preprocess, 58.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 butterfly, 56.4ms
# Speed: 2.4ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 butterflys, 56.3ms
# Speed: 2.2ms preprocess, 56.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 54.2ms
# Speed: 2.1ms preprocess, 54.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 55.5ms
# Speed: 2.2ms preprocess, 55.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 52.8ms
# Speed: 1.9ms preprocess, 52.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 52.9ms
# Speed: 2.5ms preprocess, 52.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 53.2ms
# Speed: 2.5ms preprocess, 53.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 (no detections), 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
